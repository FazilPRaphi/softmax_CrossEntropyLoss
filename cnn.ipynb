# %%
import torch

# %%
import torchvision

# %%
import torch.nn as nn

# %%
import torch.nn.functional as F

# %%
import torchvision.transforms as transforms

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
device= torch.device('cuda' if torch.cuda.is_available() else  'cpu')

# %%
num_epochs=50

# %%
batch_size=4

# %%
learning_rate=.001

# %%
transform =transforms.Compose([transforms.ToTensor(),transforms.Normalize((.5,.5,.5),(.5,.5,.5))])

# %%
train_dataset = torchvision.datasets.CIFAR10(
    root='./newdata',
    train=True,
    download=True,
    transform=transform
)

# %%
test_dataset=torchvision.datasets.CIFAR10(root='./newdata',train=False,download=True,transform=transform)

# %%
train_loader=torch.utils.data.DataLoader(train_dataset,batch_size=batch_size,shuffle=True)

# %%
test_loader=torch.utils.data.DataLoader(test_dataset,batch_size=batch_size,shuffle=True)

# %%
classes=('plane','car','bird','cat','deer','dog','frog','horse','ship','truck')

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet,self).__init__()
        self.conv1= nn.Conv2d(3,6,5)
        self.pool =nn.MaxPool2d(2,2)
        self.conv2=nn.Conv2d(6,16,5)
        self.fc1=nn.Linear(16*5*5,120)
        self.fc2=nn.Linear(120,84)
        self.fc3=nn.Linear(84,10)
    def forward(self,x):
        x=self.pool(F.relu(self.conv1(x)))
        x=self.pool(F.relu(self.conv2(x)))
        x=x.view(-1,16*5*5)
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2(x))
        x=self.fc3(x)
        return x

# %%
model= ConvNet().to(device)

FILE="model.pth"
torch.save(model,FILE)

# %%
criterion =nn.CrossEntropyLoss()

# %%
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)

# %%
n_total_steps=len(train_loader)

# %%
for epoch in range(num_epochs):
    for i,(images,labels) in enumerate (train_loader):
        images=images.to(device)
        labels=labels.to(device)
        outputs=model(images)
        loss=criterion(outputs,labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if(i+1)%2000==0:
            print(f' epoch : {epoch+1}/{num_epochs} loss : {loss.item():.4f}')
print('finished training')
# Out:
#  epoch : 1/50 loss : 2.3136
#  epoch : 1/50 loss : 2.3268
#  epoch : 1/50 loss : 2.3294
#  epoch : 1/50 loss : 2.3167
#  epoch : 1/50 loss : 2.3013
#  epoch : 1/50 loss : 2.3107
#  epoch : 2/50 loss : 2.2486
#  epoch : 2/50 loss : 1.8337
#  epoch : 2/50 loss : 1.8363
#  epoch : 2/50 loss : 2.3511
#  epoch : 2/50 loss : 1.9937
#  epoch : 2/50 loss : 1.9770
#  epoch : 3/50 loss : 1.4650
#  epoch : 3/50 loss : 1.4082
#  epoch : 3/50 loss : 1.4971
#  epoch : 3/50 loss : 1.7844
#  epoch : 3/50 loss : 1.3270
#  epoch : 3/50 loss : 1.9134
#  epoch : 4/50 loss : 1.5542
#  epoch : 4/50 loss : 1.5619
#  epoch : 4/50 loss : 0.7466
#  epoch : 4/50 loss : 1.7441
#  epoch : 4/50 loss : 1.1575
#  epoch : 4/50 loss : 2.0577
#  epoch : 5/50 loss : 1.5295
#  epoch : 5/50 loss : 1.2678
#  epoch : 5/50 loss : 1.5899
#  epoch : 5/50 loss : 1.4337
#  epoch : 5/50 loss : 2.0734
#  epoch : 5/50 loss : 1.7149
#  epoch : 6/50 loss : 1.9608
#  epoch : 6/50 loss : 2.0273
#  epoch : 6/50 loss : 1.5539
#  epoch : 33/50 loss : 1.3064
#  epoch : 33/50 loss : 0.5278
#  epoch : 33/50 loss : 0.9213
#  epoch : 33/50 loss : 0.9934
#  epoch : 33/50 loss : 0.7685
#  epoch : 34/50 loss : 0.4545
#  epoch : 34/50 loss : 0.4928
#  epoch : 34/50 loss : 0.3079
#  epoch : 34/50 loss : 0.5817
#  epoch : 34/50 loss : 0.6071
#  epoch : 34/50 loss : 1.9000
#  epoch : 35/50 loss : 0.5577
#  epoch : 35/50 loss : 0.0887
#  epoch : 35/50 loss : 0.3132
#  epoch : 35/50 loss : 0.2226
#  epoch : 35/50 loss : 0.5194
#  epoch : 35/50 loss : 0.2147
#  epoch : 36/50 loss : 0.5969
#  epoch : 36/50 loss : 0.1718
#  epoch : 36/50 loss : 0.0386
#  epoch : 36/50 loss : 0.1817
#  epoch : 36/50 loss : 0.2094
#  epoch : 36/50 loss : 0.1371
#  epoch : 37/50 loss : 0.8619
#  epoch : 37/50 loss : 1.1565
#  epoch : 37/50 loss : 1.9059
#  epoch : 37/50 loss : 0.8161
#  epoch : 37/50 loss : 0.7058
#  epoch : 37/50 loss : 0.2888
#  epoch : 38/50 loss : 1.0580
#  epoch : 38/50 loss : 0.0744
#  epoch : 38/50 loss : 0.1491
#  epoch : 38/50 loss : 0.6574
#  epoch : 38/50 loss : 0.2506
#  epoch : 38/50 loss : 1.6682
#  epoch : 39/50 loss : 3.3434
#  epoch : 39/50 loss : 0.0474
#  epoch : 39/50 loss : 0.1839
#  epoch : 39/50 loss : 0.5267
#  epoch : 39/50 loss : 0.2230
#  epoch : 39/50 loss : 0.9521
#  epoch : 40/50 loss : 0.3572
#  epoch : 40/50 loss : 0.1459
#  epoch : 40/50 loss : 0.5177
#  epoch : 40/50 loss : 0.0943
#  epoch : 40/50 loss : 0.3328
#  epoch : 40/50 loss : 0.8011
#  epoch : 41/50 loss : 0.0876
#  epoch : 41/50 loss : 0.2114
#  epoch : 41/50 loss : 0.0170
#  epoch : 41/50 loss : 0.7416
#  epoch : 41/50 loss : 0.5596

# %%
with torch.no_grad():
    n_correct=0
    n_samples=0
    n_class_correct=[0 for i in range (10)]
    n_samples_correct=[0 for i in range (10)]
    for images,labels in test_loader:
        images=images.to(device)
        labels=labels.to(device)
        output=model(images)
        _,predicted=torch.max(output,1)
        n_samples+=labels.size(0)
        n_correct+=(predicted==labels).sum().item()
        for i in range (batch_size):
            label=labels[i]
            pred=predicted[i]
            if(label==pred):
                n_class_correct[label]+=1
            n_samples_correct[label]+=1
        acc = 100.0 * n_correct / n_samples
    print(f'Total Accuracy: {acc:.2f}%')

    for i in range(10):
        acc = 100.0 * n_class_correct[i] / n_samples_correct[i]
        print(f'Class {i}: {acc:.2f}%')

# %%
with torch.no_grad():

    n_correct = 0
    n_samples = 0

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    accuracy = 100 * n_correct / n_samples

    print(f"Correct: {n_correct}")
    print(f"Total: {n_samples}")
    print(f"Accuracy: {accuracy:.2f}%")

# %%
print(len(test_loader.dataset))

# %%
model=torch.load(FILE)

model.eval()

# %%
for param in parameters():
    print(param)
